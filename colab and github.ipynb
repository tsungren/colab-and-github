# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. 練習一下markdown
# 方法和jupyter 一樣

# %%
x = np.linspace(-5, 5, 200)
y = np.sin(x)

# %%
plt.plot(x, y)
